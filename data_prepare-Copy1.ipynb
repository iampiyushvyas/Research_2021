# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
#df1=pd.read_csv('/content/drive/MyDrive/830/HGI.csv')
#df2=pd.read_csv('/content/drive/MyDrive/830/TEC.csv')
#df3=pd.read_csv('/content/drive/MyDrive/830/PS.csv')

# %%
df1=pd.read_csv('HGI.csv')
df2=pd.read_csv('TEC.csv')
df3=pd.read_csv('PS.csv')
# Out:
# C:\Users\DSU\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (12,14,17,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head(5)
# Out:
#   Facility ID                            Facility Name  \
# 0      044022                 CONWAY BEHAVIORAL HEALTH
# 1      054154               SAN JOSE BEHAVIORAL HEALTH
# 2      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC
# 3      194089              GENESIS BEHAVIORAL HOSPITAL
# 4      194114            RIVER PLACE BEHAVIORAL HEALTH
#
#                         Address           City State  ZIP Code  \
# 0             2255 STURGIS ROAD         CONWAY    AR     72034
# 1  455 SILICON VALLEY BOULEVARD       SAN JOSE    CA     95138
# 2                  FERRELL ROAD      ROSICLARE    IL     62982
# 3            606 LATIOLAIS ROAD  BREAUX BRIDGE    LA     70517
# 4              500 RUE DE SANTE       LA PLACE    LA     70068
#
#         County Name    Phone Number              Hospital Type  \
# 0          FAULKNER  (501) 205-0011                Psychiatric
# 1       SANTA CLARA  (669) 234-5959                Psychiatric
# 2            HARDIN  (618) 285-6634  Critical Access Hospitals
# 3        ST. MARTIN  (337) 442-6254                Psychiatric
# 4  ST. JOHN BAPTIST  (985) 444-5100                Psychiatric
#
#                Hospital Ownership  ...  \
# 0                     Proprietary  ...
# 1                     Proprietary  ...
# 2  Voluntary non-profit - Private  ...
# 3                     Proprietary  ...
# 4                     Proprietary  ...
#
#   Readmission national comparison footnote  \
# 0                                     19.0
# 1                                     19.0
# 2                                      NaN
# 3                                     19.0
# 4                                     19.0
#
#   Patient experience national comparison  \
# 0                          Not Available
# 1                          Not Available
# 2                          Not Available
# 3                          Not Available
# 4                          Not Available
#
#   Patient experience national comparison footnote  \
# 0                                            19.0
# 1                                            19.0
# 2                                            16.0
# 3                                            19.0
# 4                                            19.0
#
#    Effectiveness of care national comparison  \
# 0                              Not Available
# 1                              Not Available
# 2                              Not Available
# 3                              Not Available
# 4                              Not Available
#
#   Effectiveness of care national comparison footnote  \
# 0                                               19.0
# 1                                               19.0
# 2                                               16.0
# 3                                               19.0
# 4                                               19.0
#
#    Timeliness of care national comparison  \
# 0                           Not Available
# 1                           Not Available
# 2                           Not Available
# 3                           Not Available
# 4                           Not Available
#
#   Timeliness of care national comparison footnote  \
# 0                                            19.0
# 1                                            19.0
# 2                                             5.0
# 3                                            19.0
# 4                                            19.0
#
#    Efficient use of medical imaging national comparison  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Efficient use of medical imaging national comparison footnote  \
# 0                                               19.0
# 1                                               19.0
# 2                                                5.0
# 3                                               19.0
# 4                                               19.0
#
#                                 Location
# 0                                    NaN
# 1  POINT (-121.77291599999998 37.246742)
# 2                                    NaN
# 3                                    NaN
# 4           POINT (-90.514023 30.071081)
#
# [5 rows x 29 columns]

# %%
df2.head(5)
# Out:
#   Facility ID                   Facility Name                     Address  \
# 0      010005        MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 1      010052  LAKE MARTIN COMMUNITY HOSPITAL          201 MARIARDEN ROAD
# 2      010055                FLOWERS HOSPITAL       4370 WEST MAIN STREET
# 3      010059         LAWRENCE MEDICAL CENTER         202 HOSPITAL STREET
# 4      010062        WIREGRASS MEDICAL CENTER         1200 W MAPLE AVENUE
#
#         City State  ZIP Code County Name    Phone Number         Condition  \
# 0       BOAZ    AL     35957    MARSHALL  (256) 593-8310       Sepsis Care
# 1  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821       Sepsis Care
# 2     DOTHAN    AL     36305     HOUSTON  (334) 793-5000       Sepsis Care
# 3    MOULTON    AL     35650    LAWRENCE  (256) 974-2200  Colonoscopy care
# 4     GENEVA    AL     36340      GENEVA  (334) 684-3655       Sepsis Care
#
#     Measure ID                                       Measure Name  \
# 0  SEV_SEP_6HR                        Severe Sepsis 6-Hour Bundle
# 1   SEP_SH_6HR                         Septic Shock 6-Hour Bundle
# 2  SEV_SEP_6HR                        Severe Sepsis 6-Hour Bundle
# 3        OP_29  Endoscopy/polyp surveillance: appropriate foll...
# 4  SEV_SEP_6HR                        Severe Sepsis 6-Hour Bundle
#
#            Score         Sample Footnote  Start Date    End Date  \
# 0             97            159      NaN  01/01/2019  09/30/2019
# 1  Not Available  Not Available        1  01/01/2019  09/30/2019
# 2             89             93        2  01/01/2019  09/30/2019
# 3  Not Available  Not Available        1  01/01/2018  12/31/2018
# 4             58             12      NaN  01/01/2019  09/30/2019
#
#                                 Location
# 0                                    NaN
# 1             POINT (-85.741758 32.8187)
# 2           POINT (-85.457937 31.235991)
# 3           POINT (-87.286019 34.482884)
# 4  POINT (-85.890837 31.048063000000003)

# %%
df3.head(5)
# Out:
#   Facility ID                     Facility Name                     Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1      010005          MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 2      010007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 3      010011                ST. VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 4      010012    DEKALB REGIONAL MEDICAL CENTER        200 MED CENTER DRIVE
#
#          City State  ZIP Code County Name    Phone Number  \
# 0      DOTHAN    AL     36301     HOUSTON  (334) 793-8701
# 1        BOAZ    AL     35957    MARSHALL  (256) 593-8310
# 2         OPP    AL     36467   COVINGTON  (334) 493-3541
# 3  BIRMINGHAM    AL     35235   JEFFERSON  (205) 838-3122
# 4  FORT PAYNE    AL     35968     DE KALB  (256) 845-3150
#
#        HCAHPS Measure ID                                    HCAHPS Question  \
# 0    H_DOCTOR_LISTEN_U_P  Patients who reported that their doctors "Usua...
# 1   H_COMP_3_STAR_RATING                 Staff responsiveness - star rating
# 2           H_COMP_5_U_P  Patients who reported that staff "Usually" exp...
# 3  H_COMP_1_LINEAR_SCORE            Nurse communication - linear mean score
# 4           H_COMP_2_U_P  Patients who reported that their doctors "Usua...
#
#    ... HCAHPS Answer Percent HCAHPS Answer Percent Footnote  \
# 0  ...                    15                            NaN
# 1  ...        Not Applicable                            NaN
# 2  ...                    16                            NaN
# 3  ...        Not Applicable                            NaN
# 4  ...                    15                            NaN
#
#   HCAHPS Linear Mean Value Number of Completed Surveys  \
# 0           Not Applicable                         535
# 1           Not Applicable                         804
# 2           Not Applicable                         175
# 3                       90                        2251
# 4           Not Applicable                         412
#
#   Number of Completed Surveys Footnote Survey Response Rate Percent  \
# 0                                  NaN                           22
# 1                                  NaN                           32
# 2                                  NaN                           26
# 3                                  NaN                           32
# 4                                  NaN                           18
#
#   Survey Response Rate Percent Footnote  Start Date    End Date  \
# 0                                   NaN  10/01/2018  09/30/2019
# 1                                   NaN  10/01/2018  09/30/2019
# 2                                   NaN  10/01/2018  09/30/2019
# 3                                   NaN  10/01/2018  09/30/2019
# 4                                   NaN  10/01/2018  09/30/2019
#
#                                 Location
# 0           POINT (-85.361725 31.214058)
# 1                                    NaN
# 2  POINT (-86.255415 31.291971999999998)
# 3           POINT (-86.665182 33.595351)
# 4                                    NaN
#
# [5 rows x 23 columns]

# %%
data= pd.merge(df1,df2) # merge can only join two table at once therefore merge in merge.

# %%
data= pd.merge(data,df3) # merge can only join two table at once therefore merge in merge.

# %%
data.columns
# Out:
# Index(['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services',
#        'Meets criteria for promoting interoperability of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
#        'Efficient use of medical imaging national comparison',
#        'Efficient use of medical imaging national comparison footnote',
#        'Location', 'Condition', 'Measure ID', 'Measure Name', 'Score',
#        'Sample', 'Footnote', 'Start Date', 'End Date', 'HCAHPS Measure ID',
#        'HCAHPS Question', 'HCAHPS Answer Description',
#        'Patient Survey Star Rating', 'Patient Survey Star Rating Footnote',
#        'HCAHPS Answer Percent', 'HCAHPS Answer Percent Footnote',
#        'HCAHPS Linear Mean Value', 'Number of Completed Surveys',
#        'Number of Completed Surveys Footnote', 'Survey Response Rate Percent',
#        'Survey Response Rate Percent Footnote'],
#       dtype='object')

# %%
data.shape
# Out:
# (3527304, 49)

# %%
data.head(10)
# Out:
#   Facility ID                            Facility Name       Address  \
# 0      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 1      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 2      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 3      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 4      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 5      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 6      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 7      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 8      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 9      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
#
#         City State  ZIP Code County Name    Phone Number  \
# 0  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 1  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 2  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 3  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 4  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 5  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 6  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 7  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 8  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 9  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
#
#                Hospital Type              Hospital Ownership  ...  \
# 0  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 1  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 2  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 3  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 4  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 5  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 6  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 7  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 8  Critical Access Hospitals  Voluntary non-profit - Private  ...
# 9  Critical Access Hospitals  Voluntary non-profit - Private  ...
#
#                            HCAHPS Answer Description  \
# 0                    Cleanliness - linear mean score
# 1   Patients who gave a rating of "6" or lower (low)
# 2  Patients "always" received call button help as...
# 3  No, staff "did not" give patients this informa...
# 4  Patients "usually" received call button help a...
# 5            Nurse communication - linear mean score
# 6                 Doctors "always" communicated well
# 7  Patients who "Disagree" or "Strongly Disagree"...
# 8  "NO", patients would not recommend the hospita...
# 9  Doctors "sometimes" or "never" treated them wi...
#
#   Patient Survey Star Rating Patient Survey Star Rating Footnote  \
# 0             Not Applicable                                 NaN
# 1             Not Applicable                                 NaN
# 2             Not Applicable                                 NaN
# 3             Not Applicable                                 NaN
# 4             Not Applicable                                 NaN
# 5             Not Applicable                                 NaN
# 6             Not Applicable                                 NaN
# 7             Not Applicable                                 NaN
# 8             Not Applicable                                 NaN
# 9             Not Applicable                                 NaN
#
#    HCAHPS Answer Percent HCAHPS Answer Percent Footnote  \
# 0         Not Applicable                            NaN
# 1                      1                             10
# 2          Not Available                              1
# 3                     23                             10
# 4          Not Available                              1
# 5         Not Applicable                            NaN
# 6                     99                             10
# 7          Not Available                              1
# 8                      0                             10
# 9          Not Available                              1
#
#    HCAHPS Linear Mean Value Number of Completed Surveys  \
# 0             Not Available                          45
# 1            Not Applicable                          45
# 2            Not Applicable                          45
# 3            Not Applicable                          45
# 4            Not Applicable                          45
# 5             Not Available                          45
# 6            Not Applicable                          45
# 7            Not Applicable                          45
# 8            Not Applicable                          45
# 9            Not Applicable                          45
#
#    Number of Completed Surveys Footnote Survey Response Rate Percent  \
# 0                                    10                           18
# 1                                    10                           18
# 2                                    10                           18
# 3                                    10                           18
# 4                                    10                           18
# 5                                    10                           18
# 6                                    10                           18
# 7                                    10                           18
# 8                                    10                           18
# 9                                    10                           18
#
#    Survey Response Rate Percent Footnote
# 0                                     10
# 1                                     10
# 2                                     10
# 3                                     10
# 4                                     10
# 5                                     10
# 6                                     10
# 7                                     10
# 8                                     10
# 9                                     10
#
# [10 rows x 49 columns]

# %%
for col in data.columns: #see all column names
    print(col)
# Out:
# Facility ID
# Facility Name
# Address
# City
# State
# ZIP Code
# County Name
# Phone Number
# Hospital Type
# Hospital Ownership
# Emergency Services
# Meets criteria for promoting interoperability of EHRs
# Hospital overall rating
# Hospital overall rating footnote
# Mortality national comparison
# Mortality national comparison footnote
# Safety of care national comparison
# Safety of care national comparison footnote
# Readmission national comparison
# Readmission national comparison footnote
# Patient experience national comparison
# Patient experience national comparison footnote
# Effectiveness of care national comparison
# Effectiveness of care national comparison footnote
# Timeliness of care national comparison
# Timeliness of care national comparison footnote
# Efficient use of medical imaging national comparison
# Efficient use of medical imaging national comparison footnote
# Location
# Condition
# Measure ID
# Measure Name
# Score
# Sample
# Footnote
# Start Date
# End Date
# HCAHPS Measure ID
# HCAHPS Question
# HCAHPS Answer Description
# Patient Survey Star Rating
# Patient Survey Star Rating Footnote
# HCAHPS Answer Percent
# HCAHPS Answer Percent Footnote
# HCAHPS Linear Mean Value
# Number of Completed Surveys
# Number of Completed Surveys Footnote
# Survey Response Rate Percent
# Survey Response Rate Percent Footnote

# %%
# see number of rows
print(len(data.index))
# Out:
# 3527304

# %%
#!pip install pandasql # for running actual sql statements.

# %%
#import pandasql
#from pandasql import sqldf


#sqldf("select * from data where HCAHPS Measure ID like '%H_RECMND_%' and Measure ID IN ('ED-2b', 'OP-18b','OP-22','SEP-1','IIM-3') and Score >0 and HCAHPS Answer Percent >0 ;", locals())

# %%
data=data.drop(['Footnote','Hospital overall rating footnote', 'Mortality national comparison footnote',
                'Readmission national comparison footnote','Patient experience national comparison footnote',
                'Effectiveness of care national comparison footnote','Timeliness of care national comparison footnote',
                'Efficient use of medical imaging national comparison footnote','Patient Survey Star Rating Footnote',
                'HCAHPS Answer Percent Footnote','Number of Completed Surveys Footnote',
                'Survey Response Rate Percent Footnote'], axis=1)

# %%
for col in data.columns: #see all column names
    print(col)
# Out:
# Facility ID
# Facility Name
# Address
# City
# State
# ZIP Code
# County Name
# Phone Number
# Hospital Type
# Hospital Ownership
# Emergency Services
# Meets criteria for promoting interoperability of EHRs
# Hospital overall rating
# Mortality national comparison
# Safety of care national comparison
# Safety of care national comparison footnote
# Readmission national comparison
# Patient experience national comparison
# Effectiveness of care national comparison
# Timeliness of care national comparison
# Efficient use of medical imaging national comparison
# Location
# Condition
# Measure ID
# Measure Name
# Score
# Sample
# Start Date
# End Date
# HCAHPS Measure ID
# HCAHPS Question
# HCAHPS Answer Description
# Patient Survey Star Rating
# HCAHPS Answer Percent
# HCAHPS Linear Mean Value
# Number of Completed Surveys
# Survey Response Rate Percent

# %%
data.shape
# Out:
# (3527304, 37)

# %%
data.head(5)
# Out:
#   Facility ID                            Facility Name       Address  \
# 0      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 1      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 2      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 3      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
# 4      141328  HARDIN COUNTY GENERAL HOSPITAL & CLINIC  FERRELL ROAD
#
#         City State  ZIP Code County Name    Phone Number  \
# 0  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 1  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 2  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 3  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
# 4  ROSICLARE    IL     62982      HARDIN  (618) 285-6634
#
#                Hospital Type              Hospital Ownership  ...  Start Date  \
# 0  Critical Access Hospitals  Voluntary non-profit - Private  ...  10/01/2018
# 1  Critical Access Hospitals  Voluntary non-profit - Private  ...  10/01/2018
# 2  Critical Access Hospitals  Voluntary non-profit - Private  ...  10/01/2018
# 3  Critical Access Hospitals  Voluntary non-profit - Private  ...  10/01/2018
# 4  Critical Access Hospitals  Voluntary non-profit - Private  ...  10/01/2018
#
#      End Date     HCAHPS Measure ID  \
# 0  09/30/2019  H_CLEAN_LINEAR_SCORE
# 1  09/30/2019      H_HSP_RATING_0_6
# 2  09/30/2019     H_CALL_BUTTON_A_P
# 3  09/30/2019          H_COMP_6_N_P
# 4  09/30/2019     H_CALL_BUTTON_U_P
#
#                                      HCAHPS Question  \
# 0                    Cleanliness - linear mean score
# 1  Patients who gave their hospital a rating of 6...
# 2  Patients who reported that they "Always" recei...
# 3  Patients who reported that NO, they were not g...
# 4  Patients who reported that they "Usually" rece...
#
#                            HCAHPS Answer Description  \
# 0                    Cleanliness - linear mean score
# 1   Patients who gave a rating of "6" or lower (low)
# 2  Patients "always" received call button help as...
# 3  No, staff "did not" give patients this informa...
# 4  Patients "usually" received call button help a...
#
#    Patient Survey Star Rating HCAHPS Answer Percent HCAHPS Linear Mean Value  \
# 0              Not Applicable        Not Applicable            Not Available
# 1              Not Applicable                     1           Not Applicable
# 2              Not Applicable         Not Available           Not Applicable
# 3              Not Applicable                    23           Not Applicable
# 4              Not Applicable         Not Available           Not Applicable
#
#   Number of Completed Surveys Survey Response Rate Percent
# 0                          45                           18
# 1                          45                           18
# 2                          45                           18
# 3                          45                           18
# 4                          45                           18
#
# [5 rows x 37 columns]

# %%
import pandasql
from pandasql import sqldf
q="""
    SELECT * from data 
    WHERE HCAHPS Measure ID like '%H_RECMND_%' 
    AND Measure ID = 'ED_2b'
    AND Measure ID = 'OP_18b'
    AND Measure ID ='OP_22'
    AND Measure ID = 'SEP_1'
    AND Measure ID = 'IIM_3'
    AND Score > 0 
    AND HCAHPS Answer Percent > 0 ;
"""

    
data=sqldf(q, locals())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# OperationalError: near "Measure": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandasql\sqldf.py in __call__(self, query, env)
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     437             parse_dates=parse_dates,
# --> 438             chunksize=chunksize,
#     439         )
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     975         if isinstance(object_, util.string_types[0]):
# --> 976             return self._execute_text(object_, multiparams, params)
#     977         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1148             statement,
# -> 1149             parameters,
#    1150         )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# OperationalError: (sqlite3.OperationalError) near "Measure": syntax error
# [SQL:
#     select * from data
#     where HCAHPS Measure ID like '%H_RECMND_%'
#     and Measure ID IN ('ED_2b', 'OP_18b','OP_22','SEP_1','IIM_3')
#     and Score >0
#     and HCAHPS Answer Percent >0 ;
# ]
# (Background on this error at: http://sqlalche.me/e/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# <ipython-input-22-32406f169a96> in <module>
#      10
#      11
# ---> 12 data=sqldf(q, locals())
#
# ~\anaconda3\lib\site-packages\pandasql\sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# ~\anaconda3\lib\site-packages\pandasql\sqldf.py in __call__(self, query, env)
#      61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
# ---> 63                 raise PandaSQLException(ex)
#      64             except ResourceClosedError:
#      65                 # query returns nothing
#
# PandaSQLException: (sqlite3.OperationalError) near "Measure": syntax error
# [SQL:
#     select * from data
#     where HCAHPS Measure ID like '%H_RECMND_%'
#     and Measure ID IN ('ED_2b', 'OP_18b','OP_22','SEP_1','IIM_3')
#     and Score >0
#     and HCAHPS Answer Percent >0 ;
# ]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
data.to_csv('data1.csv',na_rep='Unkown', index=False) # missing value save as Unknown

# %%
df4=pd.read_csv('data1.csv')
